# %% [markdown]
# # Welcome to the session on logistic regression

# %% [markdown]
# ## let us consider an example to understand the concept of logistic regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Agenda

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # supervised learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Where does logistic regression fit in ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # logistic regression applications :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # case study

# %% [markdown]
# ![image.png](attachment:image.png)
